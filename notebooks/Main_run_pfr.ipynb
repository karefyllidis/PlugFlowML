# %% [markdown]
# # HydrAI: Plug Flow Reactor Simulation
#
# **HydrAI** = **Hydr**ocarbon + **AI** (Machine Learning)
#
# This notebook provides an interactive interface for running PFR simulations using Cantera.
#
# ## Features
# - Multi-reactant support (ethane, propane, naphtha, n-hexane)
# - Interactive configuration
# - Real-time simulation progress
# - Comprehensive visualization
# - Results export

# %%
# Setup and Imports
import sys
import os
from pathlib import Path

# IMPORTANT: Import cantera BEFORE adding src to sys.path
# This prevents namespace conflict: without this, Python would find src/cantera/ 
# (our package) instead of the actual cantera library when pfr_simulator.py imports it
import cantera as ct
print(f"Cantera version: {ct.__version__}")

# Get project root directory
# In Jupyter notebooks, we check from current working directory
current_dir = Path(os.getcwd())

# Find project root by looking for 'src' directory
if (current_dir / 'src').exists():
    project_root = current_dir
elif (current_dir.parent / 'src').exists():
    project_root = current_dir.parent
else:
    # Fallback: assume current directory is project root
    project_root = current_dir

# Add project root to path (after cantera is imported)
sys.path.insert(0, str(project_root))
print(f"Project root: {project_root}")

from src.cantera.pfr_simulator import (
    load_reactant_database,
    generate_config_for_reactant,
    setup_mechanism,
    setup_initial_conditions,
    setup_heat_flux,
    run_simulation,
    process_and_visualize_results
)

import numpy as np
import matplotlib.pyplot as plt

print("HydrAI: PFR Simulation System")
print("=" * 60)
# Out:
# Cantera version: 3.2.0
# Project root: /Users/nikolaskarefyllidis/Desktop/60_ML:AI/30 main portofolio projects/HydrAI
# HydrAI: PFR Simulation System
# ============================================================

# %% [markdown]
# ## Step 1: Select Reactant
#
# Choose the reactant you want to simulate. Available options are listed below.

# %%
# Load reactant database
database = load_reactant_database()

# Display available reactants
print("Available Reactants:")
print("-" * 60)
for key, info in database['reactants'].items():
    print(f"  {key:12s}: {info['name']:15s} - {info['description']}")
print("-" * 60)

# Set reactant here (change this to select different reactant)
REACTANT_KEY = 'n-hexane'  # Options: 'ethane', 'propane', 'naphtha', 'n-hexane'

if REACTANT_KEY not in database['reactants']:
    print(f"\n[ERROR] Reactant '{REACTANT_KEY}' not found!")
    print(f"Available reactants: {list(database['reactants'].keys())}")
else:
    reactant_info = database['reactants'][REACTANT_KEY]
    print(f"\n[OK] Selected: {reactant_info['name']} ({REACTANT_KEY})")
    print(f"    Description: {reactant_info['description']}")
# Out:
# Available Reactants:
# ------------------------------------------------------------
#   test        : Test (GRI-Mech 3.0) - Test mechanism (Cantera gri30) for pipeline validation
#   ethane      : Ethane          - Ethane steam cracking for ethylene production
#   propane     : Propane         - Propane steam cracking for olefins production
#   naphtha     : Naphtha         - Naphtha steam cracking for petrochemicals production
#   n-hexane    : n-Hexane        - n-Hexane steam cracking for olefins production
# ------------------------------------------------------------
#
# [OK] Selected: n-Hexane (n-hexane)
#     Description: n-Hexane steam cracking for olefins production

# %% [markdown]
# ## Step 2: Load Configuration
#
# Generate the simulation configuration for the selected reactant.

# %%
# Generate configuration
config = generate_config_for_reactant(REACTANT_KEY, database)
reactant_info = database['reactants'][REACTANT_KEY]

print(f"Loaded configuration for: {config['simulation_info']['title']}")
print(f"Version: {config['simulation_info']['version']}")
print(f"\nConfiguration Summary:")
print(f"  - Mechanism: {config['mechanism']['reaction_mechanism_file']}")
print(f"  - Initial Temperature: {config['initial_conditions']['temperature_K']} K")
print(f"  - Initial Pressure: {config['initial_conditions']['pressure_Pa']/1e5:.2f} bar")
print(f"  - Reactor Length: {config['reactor_geometry']['length_m']} m")
print(f"  - Reactor Diameter: {config['reactor_geometry']['diameter_m']*1000:.1f} mm")
print(f"  - Mass Flow Rate: {config['operating_conditions']['mass_flow_rate_kgps']} kg/s")
print(f"  - Number of Steps: {config['simulation_settings']['n_steps']}")
# Out:
# Loaded configuration for: n-Hexane Pyrolysis PFR Simulation
# Version: 2.1.0
#
# Configuration Summary:
#   - Mechanism: mechanisms/n-Hexane_Kinetic-Model_species_153.yaml
#   - Initial Temperature: 925.15 K
#   - Initial Pressure: 2.00 bar
#   - Reactor Length: 10.0 m
#   - Reactor Diameter: 30.0 mm
#   - Mass Flow Rate: 0.07 kg/s
#   - Number of Steps: 200

# %% [markdown]
# ## Step 3: Setup Mechanism and Initial Conditions
#
# Initialize the Cantera mechanism and set up initial conditions.

# %%
# Setup mechanism
print("Setting up mechanism...")
gas = setup_mechanism(config)
print(f"[OK] Mechanism loaded: {len(gas.species_names)} species, {len(gas.reaction_equations())} reactions")

# Setup initial conditions
print("\nSetting up initial conditions...")
T_0, p_0, composition_0, length, diameter, area, roughness, mass_flow_rate, u_0 = \
    setup_initial_conditions(gas, config)

print(f"[OK] Initial conditions set:")
print(f"  - Temperature: {T_0:.1f} K")
print(f"  - Pressure: {p_0/1e5:.2f} bar")
print(f"  - Initial velocity: {u_0:.2f} m/s")
print(f"  - Composition: {composition_0}")

# Setup heat flux
print("\nSetting up heat flux profile...")
hf, z_profile, heatflux_profile = setup_heat_flux(config)
print(f"[OK] Heat flux profile loaded: {len(heatflux_profile)} data points")
print(f"  - Average heat flux: {np.mean(heatflux_profile)/1e3:.1f} kW/m²")
# Out:
# Setting up mechanism...
# Gas mechanism contains 153 species and 2146 reactions
# [OK] Mechanism loaded: 153 species, 2146 reactions
#
# Setting up initial conditions...
# [OK] Initial conditions set:
#   - Temperature: 925.1 K
#   - Pressure: 2.00 bar
#   - Initial velocity: 91.97 m/s
#   - Composition: C6H14(1):1, Water:0.4
#
# Setting up heat flux profile...
# [OK] Heat flux profile loaded: 6 data points
#   - Average heat flux: 150.0 kW/m²

# %% [markdown]
# ## Step 4: Run Simulation
#
# Execute the PFR simulation. This may take a few minutes depending on the mechanism complexity.

# %%
# Run simulation
print("=" * 60)
print("Starting PFR Simulation...")
print("=" * 60)

import time
start_time = time.time()

states1 = run_simulation(gas, config, reactant_info, hf, T_0, p_0, 
                        length, diameter, area, roughness, mass_flow_rate, u_0)

elapsed_time = time.time() - start_time
print(f"\n[OK] Simulation completed in {elapsed_time:.2f} seconds")
print(f"  - Number of points: {len(states1.z)}")
print(f"  - Final temperature: {states1.T[-1]:.1f} K")
print(f"  - Final pressure: {states1.P[-1]/1e5:.2f} bar")
# Out:
# ============================================================
# Starting PFR Simulation...
# ============================================================
# Starting simulation with 200 steps...
# Progress: 0/200 (0%)
# Progress: 20/200 (10%)
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592469.3000523 and h = 2.23986240947945e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592469.3000523 and h = 2.23986240947945e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592469.3000523 and h = 2.23986240947945e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592469.3000523 and h = 6.52963583541212e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592469.3000523 and h = 6.52963583541212e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592469.3000523 and h = 6.52963583541212e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592469.3189778 and h = 2.07600342899033e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592469.3189778 and h = 2.07600342899033e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592469.3189778 and h = 2.07600342899033e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592469.3189778 and h = 6.35012066007635e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592469.3189778 and h = 6.35012066007635e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592469.3189778 and h = 6.35012066007635e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592469.3602405 and h = 1.93748941299818e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592469.3602405 and h = 1.93748941299818e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592469.3602405 and h = 1.93748941299818e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592469.3602405 and h = 6.18196031362334e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592469.3602405 and h = 6.18196031362334e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592469.3602405 and h = 6.18196031362334e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592469.7278711 and h = 1.8201853673332e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592469.7278711 and h = 1.8201853673332e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592469.7278711 and h = 1.8201853673332e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592469.7278711 and h = 6.02271655388861e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592469.7278711 and h = 6.02271655388861e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592469.7278711 and h = 6.02271655388861e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592469.7278711 and h = 9.26763948729061e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592469.7278711 and h = 9.26763948729061e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592469.7520351 and h = 1.72062239406613e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592469.7520351 and h = 1.72062239406613e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592469.7520351 and h = 1.72062239406613e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592469.7520351 and h = 5.8695066882999e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592469.7520351 and h = 5.8695066882999e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592469.7520351 and h = 5.8695066882999e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592469.7520351 and h = 9.03118712295724e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592469.7520351 and h = 9.03118712295724e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592469.7741622 and h = 1.6358894533967e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592469.7741622 and h = 1.6358894533967e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592469.7741622 and h = 1.6358894533967e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592469.7741622 and h = 5.73580120080765e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592469.7741622 and h = 5.73580120080765e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592469.7741622 and h = 5.73580120080765e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592469.7741622 and h = 8.81200461689976e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592469.7741622 and h = 8.81200461689976e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592470.3831225 and h = 1.56354528379475e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592470.3831225 and h = 1.56354528379475e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592470.3831225 and h = 1.56354528379475e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592470.3831225 and h = 5.5944365310705e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592470.3831225 and h = 5.5944365310705e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592470.3831225 and h = 5.5944365310705e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592470.3831225 and h = 8.60182287267533e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592470.3831225 and h = 8.60182287267533e-10 are such that t + h = t on the next step. The solver will continue anyway.
# Progress: 40/200 (20%)
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592470.4040927 and h = 1.50154546470456e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592470.4040927 and h = 1.50154546470456e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592470.4040927 and h = 1.50154546470456e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592470.4040927 and h = 5.46306524713616e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592470.4040927 and h = 5.46306524713616e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592470.4040927 and h = 5.46306524713616e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592470.4040927 and h = 8.40491390319356e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592470.4040927 and h = 8.40491390319356e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.3662972 and h = 1.44818135976553e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.3662972 and h = 1.44818135976553e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.3662972 and h = 1.44818135976553e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.3662972 and h = 5.34209377576677e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.3662972 and h = 5.34209377576677e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.3662972 and h = 5.34209377576677e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.3662972 and h = 8.22025331020772e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.3662972 and h = 8.22025331020772e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.3928756 and h = 1.40202766110125e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.3928756 and h = 1.40202766110125e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.3928756 and h = 1.40202766110125e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.3928756 and h = 5.22813177650311e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.3928756 and h = 5.22813177650311e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.3928756 and h = 5.22813177650311e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.3928756 and h = 8.04487496407482e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.3928756 and h = 8.04487496407482e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.4245834 and h = 1.36189800782263e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.4245834 and h = 1.36189800782263e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.4245834 and h = 1.36189800782263e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.4245834 and h = 5.12457484999273e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.4245834 and h = 5.12457484999273e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.4245834 and h = 5.12457484999273e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.4245834 and h = 7.88202345331242e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.4245834 and h = 7.88202345331242e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.4513338 and h = 1.32680647664218e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.4513338 and h = 1.32680647664218e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.4513338 and h = 1.32680647664218e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.4513338 and h = 5.01321443745249e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.4513338 and h = 5.01321443745249e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.4513338 and h = 5.01321443745249e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.4513338 and h = 7.7225926003164e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.4513338 and h = 7.7225926003164e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.4643563 and h = 1.29593482013718e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.4643563 and h = 1.29593482013718e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.4643563 and h = 1.29593482013718e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.4643563 and h = 4.91517831982961e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.4643563 and h = 4.91517831982961e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.4643563 and h = 4.91517831982961e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.4643563 and h = 7.57373355142512e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.4643563 and h = 7.57373355142512e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.499793 and h = 1.26860451269643e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.499793 and h = 1.26860451269643e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.499793 and h = 1.26860451269643e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.499793 and h = 4.82711733495323e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.499793 and h = 4.82711733495323e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.499793 and h = 4.82711733495323e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.499793 and h = 7.43374593831716e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.499793 and h = 7.43374593831716e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.5240407 and h = 1.24425307014148e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.5240407 and h = 1.24425307014148e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.5240407 and h = 1.24425307014148e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.5240407 and h = 4.7332005647407e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.5240407 and h = 4.7332005647407e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.5240407 and h = 4.7332005647407e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.5240407 and h = 7.29762389503431e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.5240407 and h = 7.29762389503431e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.5407041 and h = 1.22241411646961e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.5407041 and h = 1.22241411646961e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.5407041 and h = 1.22241411646961e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.5407041 and h = 4.6448280783573e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.5407041 and h = 4.6448280783573e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.5407041 and h = 4.6448280783573e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.5407041 and h = 7.16794648437999e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.5407041 and h = 7.16794648437999e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.5915421 and h = 1.20270070082845e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.5915421 and h = 1.20270070082845e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.5915421 and h = 1.20270070082845e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.5915421 and h = 4.54338933240165e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.5915421 and h = 4.54338933240165e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.5915421 and h = 4.54338933240165e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.5915421 and h = 7.03777533705707e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.5915421 and h = 7.03777533705707e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.6162955 and h = 1.1847914129044e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.6162955 and h = 1.1847914129044e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.6162955 and h = 1.1847914129044e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.6162955 and h = 4.47906867935372e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.6162955 and h = 4.47906867935372e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.6162955 and h = 4.47906867935372e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.6162955 and h = 6.92554036974549e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.6162955 and h = 6.92554036974549e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.6406776 and h = 1.16841886824247e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.6406776 and h = 1.16841886824247e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.6406776 and h = 1.16841886824247e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.6406776 and h = 4.39831875362835e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.6406776 and h = 4.39831875362835e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.6406776 and h = 4.39831875362835e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.6406776 and h = 6.811268827515e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592471.6406776 and h = 6.811268827515e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.0403603 and h = 1.15336022437704e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.0403603 and h = 1.15336022437704e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.0403603 and h = 1.15336022437704e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.0403603 and h = 4.3181731266983e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.0403603 and h = 4.3181731266983e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.0403603 and h = 4.3181731266983e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.0403603 and h = 6.69983418816132e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.0403603 and h = 6.69983418816132e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.0581882 and h = 1.13942930078537e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.0581882 and h = 1.13942930078537e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.0581882 and h = 1.13942930078537e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.0581882 and h = 4.2409764727493e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.0581882 and h = 4.2409764727493e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.0581882 and h = 4.2409764727493e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.0581882 and h = 6.5936829405379e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.0581882 and h = 6.5936829405379e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.0790145 and h = 1.12647023428471e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.0790145 and h = 1.12647023428471e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.0790145 and h = 1.12647023428471e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.0790145 and h = 4.16217204255063e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.0790145 and h = 4.16217204255063e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.0790145 and h = 4.16217204255063e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.0790145 and h = 6.48927078222131e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.0790145 and h = 6.48927078222131e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.1212888 and h = 1.11435215052657e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.1212888 and h = 1.11435215052657e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.1212888 and h = 1.11435215052657e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.1212888 and h = 4.08267857437974e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.1212888 and h = 4.08267857437974e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.1212888 and h = 4.08267857437974e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.1212888 and h = 6.38719687663771e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.1212888 and h = 6.38719687663771e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.1212888 and h = 6.38719687663771e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.1212888 and h = 6.38719687663771e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3533][CVode] The above warning has been issued mxhnil times and will not be issued again for this problem.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.1414801 and h = 1.10296484769183e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.1414801 and h = 1.10296484769183e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.1414801 and h = 1.10296484769183e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.1414801 and h = 4.00314846453626e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.1414801 and h = 4.00314846453626e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.1414801 and h = 4.00314846453626e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.1414801 and h = 6.28731988973656e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.1414801 and h = 6.28731988973656e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.1414801 and h = 6.28731988973656e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.1414801 and h = 6.28731988973656e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3533][CVode] The above warning has been issued mxhnil times and will not be issued again for this problem.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.1535766 and h = 1.09221525585013e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.1535766 and h = 1.09221525585013e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.1535766 and h = 1.09221525585013e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.1535766 and h = 3.8760783557521e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.1535766 and h = 3.8760783557521e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.1535766 and h = 3.8760783557521e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.1535766 and h = 6.16845049196197e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.1535766 and h = 6.16845049196197e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.1535766 and h = 6.16845049196197e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.1535766 and h = 6.16845049196197e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3533][CVode] The above warning has been issued mxhnil times and will not be issued again for this problem.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.170863 and h = 1.08202452107562e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.170863 and h = 1.08202452107562e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.170863 and h = 1.08202452107562e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.170863 and h = 3.83486292676451e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.170863 and h = 3.83486292676451e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.170863 and h = 3.83486292676451e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.170863 and h = 6.08979166309791e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.170863 and h = 6.08979166309791e-10 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15592472.170863 and h = 6.08979166309791e-10 are such that t + h = t on the next step. The solver will continue anyway.
# ...
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.0567406 and h = 2.58663020771788e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.0567406 and h = 2.58663020771788e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.0567406 and h = 2.58663020771788e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.0567406 and h = 2.58663020771788e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3533][CVode] The above warning has been issued mxhnil times and will not be issued again for this problem.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.0854723 and h = 1.0647618500572e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.0854723 and h = 1.0647618500572e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.0854723 and h = 2.52652012116628e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.0854723 and h = 2.52652012116628e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.0854723 and h = 2.52652012116628e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.0854723 and h = 2.52652012116628e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.0854723 and h = 2.52652012116628e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.0854723 and h = 2.52652012116628e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.0854723 and h = 2.52652012116628e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.0854723 and h = 2.52652012116628e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3533][CVode] The above warning has been issued mxhnil times and will not be issued again for this problem.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.0933809 and h = 1.05838010908265e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.0933809 and h = 1.05838010908265e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.0933809 and h = 2.4679021302378e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.0933809 and h = 2.4679021302378e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.0933809 and h = 2.4679021302378e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.0933809 and h = 2.4679021302378e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.0933809 and h = 2.4679021302378e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.0933809 and h = 2.4679021302378e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.0933809 and h = 2.4679021302378e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.0933809 and h = 2.4679021302378e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3533][CVode] The above warning has been issued mxhnil times and will not be issued again for this problem.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.0986843 and h = 1.05202126898049e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.0986843 and h = 1.05202126898049e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.0986843 and h = 2.41073726503228e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.0986843 and h = 2.41073726503228e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.0986843 and h = 2.41073726503228e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.0986843 and h = 2.41073726503228e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank
# [OK] Simulation completed in 12.72 seconds
#   - Number of points: 200
#   - Final temperature: 1146.3 K
#   - Final pressure: 1.56 bar
#  0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.0986843 and h = 2.41073726503228e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.0986843 and h = 2.41073726503228e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.0986843 and h = 2.41073726503228e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.0986843 and h = 2.41073726503228e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3533][CVode] The above warning has been issued mxhnil times and will not be issued again for this problem.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.1169077 and h = 1.04568499095494e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.1169077 and h = 1.04568499095494e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.1169077 and h = 2.35498732471528e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.1169077 and h = 2.35498732471528e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.1169077 and h = 2.35498732471528e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.1169077 and h = 2.35498732471528e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.1169077 and h = 2.35498732471528e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.1169077 and h = 2.35498732471528e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.1169077 and h = 2.35498732471528e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.1169077 and h = 2.35498732471528e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3533][CVode] The above warning has been issued mxhnil times and will not be issued again for this problem.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.1407884 and h = 1.03937093124565e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.1407884 and h = 1.03937093124565e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.1407884 and h = 2.30061432396591e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.1407884 and h = 2.30061432396591e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.1407884 and h = 2.30061432396591e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.1407884 and h = 2.30061432396591e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.1407884 and h = 2.30061432396591e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.1407884 and h = 2.30061432396591e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.1407884 and h = 2.30061432396591e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.1407884 and h = 2.30061432396591e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3533][CVode] The above warning has been issued mxhnil times and will not be issued again for this problem.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.1494671 and h = 1.03307875601003e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.1494671 and h = 1.03307875601003e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.1494671 and h = 2.24758275605465e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.1494671 and h = 2.24758275605465e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.1494671 and h = 2.24758275605465e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.1494671 and h = 2.24758275605465e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.1494671 and h = 2.24758275605465e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.1494671 and h = 2.24758275605465e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.1494671 and h = 2.24758275605465e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3528][CVode] Internal t = 15593478.1494671 and h = 2.24758275605465e-12 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/Users/runner/work/_temp/sundials-7.4.0/src/cvodes/cvodes.c:3533][CVode] The above warning has been issued mxhnil times and will not be issued again for this problem.

# %% [markdown]
# ## Step 5: Process Results and Visualize
#
# Generate visualizations and calculate key performance metrics.

# %%
# Process and visualize results
print("Processing results and generating visualizations...")
conversion, yields = process_and_visualize_results(gas, states1, config, 
                                                  reactant_info, hf, T_0, p_0, u_0)

print("[OK] Results processed and visualizations generated")
# Out:
# Processing results and generating visualizations...
# Simulation completed!
# Final temperature: 1146.3 K
# Final pressure: 1.56 bar
# n-Hexane conversion: 76.9%
# Product yields:
#   Ethylene: 25.22% (mass)
#   Propylene: 11.27% (mass)
#   Butadiene: 2.30% (mass)
#   Methane: 7.55% (mass)
#   Hydrogen: 0.41% (mass)
#   Acetylene: 0.00% (mass)
#   Butene: 3.65% (mass)
#   Pentadiene: 0.18% (mass)
#   Benzene: 0.00% (mass)
#   Hexadiene: 0.01% (mass)
# Plot generation disabled by configuration
# CSV export disabled by configuration
# [OK] Results processed and visualizations generated

# %% [markdown]
# ## Step 6: Results Summary
#
# Display key simulation results and performance metrics.

# %%
# Calculate residence time
residence_time = np.trapezoid(1/states1.velocity, states1.z)

# Display summary
print("=" * 60)
print("SIMULATION COMPLETED SUCCESSFULLY!")
print("=" * 60)
print(f"[OK] {reactant_info['name']} conversion: {conversion:.1f}%")
print(f"[OK] Temperature rise: {states1.T[-1] - T_0:.1f} K")
print(f"[OK] Pressure drop: {(p_0 - states1.P[-1])/1e5:.2f} bar")
print(f"[OK] Residence time: {residence_time:.3f} s")
print(f"\n[OK] Product Yields:")
for product, yield_val in yields.items():
    print(f"  - {product}: {yield_val:.2f}%")
print(f"\n[OK] Files generated:")
print(f"  - outputs/figures/*.png: Visualization plots")
print(f"  - outputs/results/*.csv: Simulation data")
print(f"  - outputs/results/*.dat: Simulation summary")
print("=" * 60)
# Out:
# ============================================================
# SIMULATION COMPLETED SUCCESSFULLY!
# ============================================================
# [OK] n-Hexane conversion: 76.9%
# [OK] Temperature rise: 221.1 K
# [OK] Pressure drop: 0.44 bar
# [OK] Residence time: 0.072 s
#
# [OK] Product Yields:
#   - Ethylene: 25.22%
#   - Propylene: 11.27%
#   - Butadiene: 2.30%
#   - Methane: 7.55%
#   - Hydrogen: 0.41%
#   - Acetylene: 0.00%
#   - Butene: 3.65%
#   - Pentadiene: 0.18%
#   - Benzene: 0.00%
#   - Hexadiene: 0.01%
#
# [OK] Files generated:
#   - outputs/figures/*.png: Visualization plots
#   - outputs/results/*.csv: Simulation data
#   - outputs/results/*.dat: Simulation summary
# ============================================================

# %% [markdown]
# ## Quick Visualization
#
# Display key profiles inline in the notebook.

# %%
# Quick inline visualization
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# Temperature profile
axes[0, 0].plot(states1.z, states1.T, 'r-', linewidth=2)
axes[0, 0].set_xlabel('Reactor Position [m]')
axes[0, 0].set_ylabel('Temperature [K]')
axes[0, 0].set_title('Temperature Profile')
axes[0, 0].grid(True, alpha=0.3)

# Pressure profile
axes[0, 1].plot(states1.z, states1.P/1e5, 'b-', linewidth=2)
axes[0, 1].set_xlabel('Reactor Position [m]')
axes[0, 1].set_ylabel('Pressure [bar]')
axes[0, 1].set_title('Pressure Profile')
axes[0, 1].grid(True, alpha=0.3)

# Velocity profile
axes[1, 0].plot(states1.z, states1.velocity, 'g-', linewidth=2)
axes[1, 0].set_xlabel('Reactor Position [m]')
axes[1, 0].set_ylabel('Velocity [m/s]')
axes[1, 0].set_title('Velocity Profile')
axes[1, 0].grid(True, alpha=0.3)

# Reactant conversion
# Get species index - handle species name format (may have :1 suffix)
feed_species = reactant_info['feed_species']
# Remove :1 suffix if present (format from database vs mechanism)
species_name = feed_species.split(':')[0] if ':' in feed_species else feed_species

try:
    species_idx = gas.species_index(species_name)
except:
    # Fallback: search for species by partial match
    species_idx = None
    for i, species in enumerate(gas.species_names):
        if species_name in species or reactant_info['name'].lower() in species.lower():
            species_idx = i
            break
    if species_idx is None:
        raise ValueError(f"Could not find species: {feed_species} (tried: {species_name})")

# Access mass fractions from SolutionArray using 2D indexing: states1.Y[:, species_idx]
reactant_mass_frac = states1.Y[:, species_idx]
conversion_profile = (1 - reactant_mass_frac / reactant_mass_frac[0]) * 100
axes[1, 1].plot(states1.z, conversion_profile, 'm-', linewidth=2)
axes[1, 1].set_xlabel('Reactor Position [m]')
axes[1, 1].set_ylabel('Conversion [%]')
axes[1, 1].set_title(f'{reactant_info["name"]} Conversion Profile')
axes[1, 1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print("\n[OK] Inline visualizations displayed above")
# Out:
# [OK] Inline visualizations displayed above

# %%
# Combined Reactant Conversion and Product Formation
fig, ax = plt.subplots(figsize=(12, 7))

# Get reactant conversion profile
feed_species = reactant_info['feed_species']
species_name = feed_species.split(':')[0] if ':' in feed_species else feed_species

try:
    species_idx = gas.species_index(species_name)
except:
    # Fallback: search for species by partial match
    species_idx = None
    for i, species in enumerate(gas.species_names):
        if species_name in species or reactant_info['name'].lower() in species.lower():
            species_idx = i
            break
    if species_idx is None:
        raise ValueError(f"Could not find species: {feed_species}")

# Calculate reactant conversion
reactant_mass_frac = states1.Y[:, species_idx]
conversion_profile = (1 - reactant_mass_frac / reactant_mass_frac[0]) * 100

# Plot reactant conversion (increasing) or reactant remaining (decreasing)
# Option 1: Show conversion (0% to 100% as reactant is consumed)
conversion_profile = (1 - reactant_mass_frac / reactant_mass_frac[0]) * 100
# Option 2: Show reactant remaining (100% to 0% as reactant is consumed)
reactant_remaining = (reactant_mass_frac / reactant_mass_frac[0]) * 100

# Plot reactant remaining (decreasing) - this shows reactant disappearing
ax.plot(states1.z, reactant_remaining, 'r-', linewidth=3, label=f'{reactant_info["name"]} Remaining')

# Get target products and plot their formation
target_products = reactant_info.get('target_products', [])
product_names = reactant_info.get('product_names', [])
colors = ['blue', 'green', 'orange', 'purple', 'brown', 'pink', 'gray', 'olive', 'cyan', 'magenta']

# Calculate and plot product yields (as percentage of initial reactant)
initial_reactant_mass = reactant_mass_frac[0]
for i, product in enumerate(target_products):
    try:
        # Handle product name format (may have :1 suffix)
        product_name_clean = product.split(':')[0] if ':' in product else product
        product_idx = gas.species_index(product_name_clean)
        
        # Get product mass fraction profile
        product_mass_frac = states1.Y[:, product_idx]
        
        # Calculate product yield as percentage of initial reactant
        # Product yield = (product mass fraction / initial reactant mass fraction) * 100
        # This shows how much product is formed relative to initial reactant
        product_yield = (product_mass_frac / initial_reactant_mass) * 100
        
        product_name = product_names[i] if i < len(product_names) else product_name_clean
        ax.plot(states1.z, product_yield, 
                color=colors[i % len(colors)], linewidth=2, 
                label=product_name, linestyle='-')
    except:
        continue

ax.set_xlabel('Reactor Position [m]', fontsize=12)
ax.set_ylabel('Reactant Remaining / Product Yield [%]', fontsize=12)
ax.set_title(f'{reactant_info["name"]} Consumption and Product Formation', fontsize=14, fontweight='bold')
ax.legend(loc='best', fontsize=10, ncol=2)
ax.grid(True, alpha=0.3)
ax.set_xlim(left=0)
ax.set_ylim(bottom=0)

plt.tight_layout()
plt.show()

print("\n[OK] Combined conversion and product formation plot displayed above")
# Out:
# [OK] Combined conversion and product formation plot displayed above
