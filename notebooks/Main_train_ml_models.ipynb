# %% [markdown]
# # HydrAI: ML Model Training
#
# This notebook will provide an interactive interface for training ML surrogate models.
#
# ## Status: Coming Soon
#
# This notebook is currently under development. It will allow you to:
# - Load training datasets
# - Configure ML model hyperparameters
# - Train multiple ML algorithms (Neural Networks, Random Forest, XGBoost, etc.)
# - Evaluate model performance
# - Compare different models
# - Save trained models for inference
#
# ## For Now
#
# Use the command-line script:
# ```bash
# python src/ml/model_training.py configs/ml_training_config.json
# ```
#
# See `docs/ml/README.md` for detailed documentation.
